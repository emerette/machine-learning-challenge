# %% [markdown]
# # Basic Data Cleaning

# %%
import pandas as pd

# %%
exoplanets = pd.read_csv('cumulative.csv')
exoplanets.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
exoplanets.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
exoplanets_df = exoplanets[['kepid', 'kepoi_name', 'koi_disposition', 'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',\
                           'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_time0bk', 'koi_impact', 'koi_duration',\
                           'koi_depth', 'koi_prad', 'koi_teq', 'koi_insol', 'koi_model_snr', 'koi_steff', 'koi_slogg',\
                           'koi_srad', 'ra', 'dec', 'koi_kepmag']]

# %%
exoplanets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   kepid             9564 non-null   int64
#  1   kepoi_name        9564 non-null   object
#  2   koi_disposition   9564 non-null   object
#  3   koi_pdisposition  9564 non-null   object
#  4   koi_score         8054 non-null   float64
#  5   koi_fpflag_nt     9564 non-null   int64
#  6   koi_fpflag_ss     9564 non-null   int64
#  7   koi_fpflag_co     9564 non-null   int64
#  8   koi_fpflag_ec     9564 non-null   int64
#  9   koi_period        9564 non-null   float64
#  10  koi_time0bk       9564 non-null   float64
#  11  koi_impact        9201 non-null   float64
#  12  koi_duration      9564 non-null   float64
#  13  koi_depth         9201 non-null   float64
#  14  koi_prad          9201 non-null   float64
#  15  koi_teq           9201 non-null   float64
# ...

# %%
null_rows = exoplanets_df.loc[exoplanets_df['koi_score'].isna()]
null_rows.head()
# Out:
#         kepid kepoi_name koi_disposition koi_pdisposition  koi_score  \
# 24    2306756  K00113.01  FALSE POSITIVE   FALSE POSITIVE        NaN
# 75   12459725  K00789.01  FALSE POSITIVE   FALSE POSITIVE        NaN
# 99    3832474  K00806.03       CONFIRMED        CANDIDATE        NaN
# 122   5115978  K00823.01       CANDIDATE        CANDIDATE        NaN
# 317  10460629  K01168.01       CANDIDATE        CANDIDATE        NaN
#
#      koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 24               0              1              0              0  386.603053
# 75               0              0              0              1   14.179819
# 99               0              0              0              0   29.159862
# 122              0              0              0              0    1.028437
# 317              0              0              0              0  856.672115
#
#      ...  koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff  koi_slogg  \
# ...

# %%
exoplanets_df_drop_null = exoplanets_df.dropna()
clean_exoplanets_df = exoplanets_df_drop_null.reset_index(drop = True)

# %%
# Check if null rows were dropped
clean_exoplanets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7994 entries, 0 to 7993
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   kepid             7994 non-null   int64
#  1   kepoi_name        7994 non-null   object
#  2   koi_disposition   7994 non-null   object
#  3   koi_pdisposition  7994 non-null   object
#  4   koi_score         7994 non-null   float64
#  5   koi_fpflag_nt     7994 non-null   int64
#  6   koi_fpflag_ss     7994 non-null   int64
#  7   koi_fpflag_co     7994 non-null   int64
#  8   koi_fpflag_ec     7994 non-null   int64
#  9   koi_period        7994 non-null   float64
#  10  koi_time0bk       7994 non-null   float64
#  11  koi_impact        7994 non-null   float64
#  12  koi_duration      7994 non-null   float64
#  13  koi_depth         7994 non-null   float64
#  14  koi_prad          7994 non-null   float64
#  15  koi_teq           7994 non-null   float64
# ...

# %%
clean_exoplanets_df.to_csv('kepler_planets.csv', index = False)
